# %%
import sys
sys.path.append('../')
from functions import *
import seaborn as sns
from matplotlib import pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### データ読込

# %%
task, target = 'consistent', 'SalesSum'
in_dir = f'../data/two_years_each/val/{task}'
df_train_X, df_train_Y, df_val_X, df_val_Y = read_data(in_dir, target)
# Out:
# ../functions.py:28: FutureWarning: `weekday_name` is deprecated and will be removed in a future version. Use `day_name` instead
#   return m[x.name.weekday_name]
# ../functions.py:24: FutureWarning: `weekday_name` is deprecated and will be removed in a future version. Use `day_name` instead
#   return 1 if x.name.weekday_name in ['Saturday', 'Sunday'] else 0

# %% [markdown]
# ### 目的変数の分布

# %%
sns.distplot(df_train_Y[target])
plt.plot()
# Out:
# []

# %% [markdown]
# ### データ構造転換

# %%
d_train_sales, d_val_sales, d_val = mtx_trans(target, df_train_X, df_train_Y, df_val_X, df_val_Y)
# Out:
# /Users/dushu/opt/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /Users/dushu/opt/anaconda3/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %% [markdown]
# ### パラメータのベイズ最適化

# %%
#params = optimize()
#params

# %% [markdown]
# ### xgboost のバリデーションモデルを作成
# - 最適化されたパラメータでモデルを作成

# %%
params = {'alpha': 0.057837101935954684,
 'colsample_bytree': 0.8,
 'eta': 0.07500000000000001,
 'gamma': 5.208659711281603e-05,
 'lambda': 0.011065383517695773,
 'max_depth': 3,
 'min_child_weight': 1.3327693248801977,
 'n_estimators': 401.0,
 'subsample': 0.8500000000000001}

model, evals_result = train2(d_train_sales, d_val_sales, params)
best_iter = model.best_iteration
# Out:
# [0]	train-rmse:14.0992	eval-rmse:12.6455
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:13.3203	eval-rmse:12.0536
# [2]	train-rmse:12.6124	eval-rmse:11.5241
# [3]	train-rmse:11.9727	eval-rmse:11.05
# [4]	train-rmse:11.3949	eval-rmse:10.6287
# [5]	train-rmse:10.8743	eval-rmse:10.2521
# [6]	train-rmse:10.4032	eval-rmse:9.91218
# [7]	train-rmse:9.98063	eval-rmse:9.61233
# [8]	train-rmse:9.60287	eval-rmse:9.35017
# [9]	train-rmse:9.26558	eval-rmse:9.11694
# [10]	train-rmse:8.96674	eval-rmse:8.92015
# [11]	train-rmse:8.70002	eval-rmse:8.74217
# [12]	train-rmse:8.46413	eval-rmse:8.58423
# [13]	train-rmse:8.25477	eval-rmse:8.43903
# [14]	train-rmse:8.06949	eval-rmse:8.31847
# [15]	train-rmse:7.90687	eval-rmse:8.22379
# [16]	train-rmse:7.76436	eval-rmse:8.13001
# [17]	train-rmse:7.63814	eval-rmse:8.05297
# [18]	train-rmse:7.52623	eval-rmse:7.97863
# [19]	train-rmse:7.43029	eval-rmse:7.91499
# [20]	train-rmse:7.34507	eval-rmse:7.86052
# [21]	train-rmse:7.27188	eval-rmse:7.81363
# [22]	train-rmse:7.20678	eval-rmse:7.78297
# [23]	train-rmse:7.14914	eval-rmse:7.74524
# [24]	train-rmse:7.09975	eval-rmse:7.71166
# [25]	train-rmse:7.05668	eval-rmse:7.68958
# [26]	train-rmse:7.01786	eval-rmse:7.66277
# [27]	train-rmse:6.98442	eval-rmse:7.64127
# [28]	train-rmse:6.95483	eval-rmse:7.63019
# [29]	train-rmse:6.92883	eval-rmse:7.60853
# [30]	train-rmse:6.90586	eval-rmse:7.59001
# [31]	train-rmse:6.88419	eval-rmse:7.57875
# [32]	train-rmse:6.86612	eval-rmse:7.56688
# [33]	train-rmse:6.85044	eval-rmse:7.55218
# [34]	train-rmse:6.83547	eval-rmse:7.5468
# [35]	train-rmse:6.82273	eval-rmse:7.53606
# [36]	train-rmse:6.81021	eval-rmse:7.52958
# [37]	train-rmse:6.80018	eval-rmse:7.52123
# [38]	train-rmse:6.79063	eval-rmse:7.5153
# [39]	train-rmse:6.78129	eval-rmse:7.50745
# [40]	train-rmse:6.77411	eval-rmse:7.50108
# [41]	train-rmse:6.76683	eval-rmse:7.49667
# [42]	train-rmse:6.76128	eval-rmse:7.49261
# [43]	train-rmse:6.75529	eval-rmse:7.48943
# [44]	train-rmse:6.74964	eval-rmse:7.48691
# [45]	train-rmse:6.74442	eval-rmse:7.48337
# [46]	train-rmse:6.74032	eval-rmse:7.48073
# [47]	train-rmse:6.73602	eval-rmse:7.47858
# [48]	train-rmse:6.73193	eval-rmse:7.47553
# [49]	train-rmse:6.72865	eval-rmse:7.47436
# [50]	train-rmse:6.7252	eval-rmse:7.47284
# [51]	train-rmse:6.72207	eval-rmse:7.47111
# [52]	train-rmse:6.71824	eval-rmse:7.46571
# [53]	train-rmse:6.71565	eval-rmse:7.46432
# [54]	train-rmse:6.71192	eval-rmse:7.46174
# [55]	train-rmse:6.7094	eval-rmse:7.46082
# [56]	train-rmse:6.70692	eval-rmse:7.46065
# [57]	train-rmse:6.70426	eval-rmse:7.45773
# [58]	train-rmse:6.70112	eval-rmse:7.45837
# [59]	train-rmse:6.69905	eval-rmse:7.46121
# [60]	train-rmse:6.69684	eval-rmse:7.45966
# [61]	train-rmse:6.69349	eval-rmse:7.45665
# [62]	train-rmse:6.69129	eval-rmse:7.45432
# [63]	train-rmse:6.68813	eval-rmse:7.44963
# [64]	train-rmse:6.6864	eval-rmse:7.44849
# [65]	train-rmse:6.68475	eval-rmse:7.44684
# [66]	train-rmse:6.68205	eval-rmse:7.44508
# [67]	train-rmse:6.67794	eval-rmse:7.44715
# [68]	train-rmse:6.67586	eval-rmse:7.45001
# [69]	train-rmse:6.67413	eval-rmse:7.45176
# [70]	train-rmse:6.67233	eval-rmse:7.45318
# [71]	train-rmse:6.67066	eval-rmse:7.4542
# [72]	train-rmse:6.66869	eval-rmse:7.45273
# [73]	train-rmse:6.66753	eval-rmse:7.45196
# [74]	train-rmse:6.6655	eval-rmse:7.45252
# [75]	train-rmse:6.66421	eval-rmse:7.45174
# [76]	train-rmse:6.66232	eval-rmse:7.45117
# [77]	train-rmse:6.66019	eval-rmse:7.45208
# [78]	train-rmse:6.65934	eval-rmse:7.45283
# [79]	train-rmse:6.65484	eval-rmse:7.44832
# [80]	train-rmse:6.65381	eval-rmse:7.44456
# [81]	train-rmse:6.65186	eval-rmse:7.44452
# [82]	train-rmse:6.64774	eval-rmse:7.44454
# [83]	train-rmse:6.64588	eval-rmse:7.44621
# [84]	train-rmse:6.64306	eval-rmse:7.44726
# [85]	train-rmse:6.6407	eval-rmse:7.44544
# [86]	train-rmse:6.63899	eval-rmse:7.44812
# [87]	train-rmse:6.63682	eval-rmse:7.44512
# [88]	train-rmse:6.63527	eval-rmse:7.44186
# [89]	train-rmse:6.63151	eval-rmse:7.43792
# [90]	train-rmse:6.62931	eval-rmse:7.43784
# [91]	train-rmse:6.62836	eval-rmse:7.44052
# [92]	train-rmse:6.62639	eval-rmse:7.44282
# [93]	train-rmse:6.62434	eval-rmse:7.4423
# [94]	train-rmse:6.62244	eval-rmse:7.44257
# [95]	train-rmse:6.62124	eval-rmse:7.44296
# [96]	train-rmse:6.61979	eval-rmse:7.44189
# [97]	train-rmse:6.61662	eval-rmse:7.43892
# [98]	train-rmse:6.61472	eval-rmse:7.43992
# [99]	train-rmse:6.61372	eval-rmse:7.4411
# [100]	train-rmse:6.6123	eval-rmse:7.44319
# [101]	train-rmse:6.61012	eval-rmse:7.44158
# [102]	train-rmse:6.6083	eval-rmse:7.43887
# [103]	train-rmse:6.60717	eval-rmse:7.43786
# [104]	train-rmse:6.6062	eval-rmse:7.43707
# [105]	train-rmse:6.60481	eval-rmse:7.43618
# [106]	train-rmse:6.60354	eval-rmse:7.43473
# [107]	train-rmse:6.60288	eval-rmse:7.43213
# [108]	train-rmse:6.60039	eval-rmse:7.43163
# [109]	train-rmse:6.59958	eval-rmse:7.43276
# [110]	train-rmse:6.59829	eval-rmse:7.43198
# [111]	train-rmse:6.59706	eval-rmse:7.43133
# [112]	train-rmse:6.59475	eval-rmse:7.43375
# [113]	train-rmse:6.59386	eval-rmse:7.4342
# [114]	train-rmse:6.59216	eval-rmse:7.43473
# [115]	train-rmse:6.5896	eval-rmse:7.43318
# [116]	train-rmse:6.58778	eval-rmse:7.44105
# [117]	train-rmse:6.58612	eval-rmse:7.44043
# [118]	train-rmse:6.58358	eval-rmse:7.43832
# [119]	train-rmse:6.58187	eval-rmse:7.44384
# [120]	train-rmse:6.58062	eval-rmse:7.4416
# [121]	train-rmse:6.57923	eval-rmse:7.44058
# [122]	train-rmse:6.57771	eval-rmse:7.44061
# [123]	train-rmse:6.57726	eval-rmse:7.44032
# [124]	train-rmse:6.5757	eval-rmse:7.44103
# [125]	train-rmse:6.57399	eval-rmse:7.43952
# [126]	train-rmse:6.57206	eval-rmse:7.43959
# [127]	train-rmse:6.57035	eval-rmse:7.44137
# [128]	train-rmse:6.56933	eval-rmse:7.44318
# [129]	train-rmse:6.5679	eval-rmse:7.44331
# [130]	train-rmse:6.56642	eval-rmse:7.4422
# [131]	train-rmse:6.56476	eval-rmse:7.44367
# Stopping. Best iteration:
# [111]	train-rmse:6.59706	eval-rmse:7.43133

# %% [markdown]
# ### 損失関数の曲線

# %%
def draw_loss(evals_result):
    train_metric = evals_result['train']['rmse']
    plt.plot(train_metric, label='train rmse')
    eval_metric = evals_result['eval']['rmse']
    plt.plot(eval_metric, label='eval rmse')
    plt.grid()
    plt.legend()
    plt.title('loss curves')
    plt.xlabel('rounds')
    plt.ylabel('rmse')
    plt.show()
draw_loss(evals_result)

# %% [markdown]
# ### バリデーション結果と実測値

# %%
def draw_preds(model, d_val, df_val_Y, target, pred_type='validation'):
    d_pred_log = model.predict(d_val)
    d_pred = np.exp(d_pred_log)
    
    df_val_Y[f'{target}_pred'] = d_pred
    df_val_Y.to_excel(f'./output/{target}_{pred_type}.xlsx')

    plt.figure(figsize=(15,5))
    plt.plot(df_val_Y[target].values, label='real')
    plt.plot(d_pred, label='pred')
    plt.title('real and predicted values')
    plt.legend()
    plt.grid()
    plt.show()
draw_preds(model, d_val, df_val_Y, target)

# %% [markdown]
# ### 特徴量の寄与度

# %%
def draw_feat_importances(model):
    _, ax = plt.subplots(figsize=(15,30))
    xgb.plot_importance(model, ax=ax, importance_type='gain')
    plt.show()
draw_feat_importances(model)

# %%
fi = get_feat_importances(model)
fi[:30]
# Out:
# ['SalesSum_0',
#  'SalesSum_4',
#  'SalesSum_6',
#  'ClicksSum_0',
#  'SalesSum_5',
#  'SalesSum_2',
#  'Clicks_1',
#  'Clicks_0',
#  'ClicksSum_3',
#  'SalesSum_3',
#  'Sales_0',
#  'Sales_3',
#  'Sales_4',
#  'Sales_2',
#  'ClicksSum_6',
#  'Sales_1',
#  'CostSum_0',
#  'Audience_2',
#  'SalesSum_1',
#  'MarketId',
#  'Impressions_2',
#  'Impressions_1',
#  'ClicksSum_4',
#  'UnitsRent_3',
#  'Sales_5',
#  'UnitsRent_4',
#  'UnitsRent_6',
#  'UnitsRent_5',
#  'AdvertiserId',
#  'ImpressionsSum_1']

# %% [markdown]
# ### 最適化されたパラメータで予測モデルを作成
# - テスト１：~2019/12/4を学習して2019/12/5~2019/12/11一週間を予測

# %%
# データの読込と前処理
in_dir = f'../data/two_years_each/test_1/{task}'
df_train_X, df_train_Y, df_val_X, df_val_Y = read_data(in_dir, target)

# xgboost のデータ構造に転換
d_train_sales, d_val_sales, d_val = mtx_trans(target, df_train_X, df_train_Y, df_val_X, df_val_Y)

# %%
# バリデーションにおいて最適化されたパラメータで学習
model, evals_result = train2(d_train_sales, d_val_sales, params, best_iter=best_iter, esr=None)
# Out:
# [0]	train-rmse:14.0387	eval-rmse:12.6352
# [1]	train-rmse:13.2675	eval-rmse:12.0251
# [2]	train-rmse:12.5691	eval-rmse:11.4777
# [3]	train-rmse:11.938	eval-rmse:11.0006
# [4]	train-rmse:11.3664	eval-rmse:10.5601
# [5]	train-rmse:10.8534	eval-rmse:10.1698
# [6]	train-rmse:10.3893	eval-rmse:9.80333
# [7]	train-rmse:9.97007	eval-rmse:9.48334
# [8]	train-rmse:9.59703	eval-rmse:9.20225
# [9]	train-rmse:9.26543	eval-rmse:8.95412
# [10]	train-rmse:8.96917	eval-rmse:8.72051
# [11]	train-rmse:8.70634	eval-rmse:8.52047
# [12]	train-rmse:8.47311	eval-rmse:8.34655
# [13]	train-rmse:8.26557	eval-rmse:8.1971
# [14]	train-rmse:8.08347	eval-rmse:8.04624
# [15]	train-rmse:7.92319	eval-rmse:7.91582
# [16]	train-rmse:7.78209	eval-rmse:7.81714
# [17]	train-rmse:7.65794	eval-rmse:7.71137
# [18]	train-rmse:7.54793	eval-rmse:7.62306
# [19]	train-rmse:7.45226	eval-rmse:7.54068
# [20]	train-rmse:7.36953	eval-rmse:7.48478
# [21]	train-rmse:7.29612	eval-rmse:7.42598
# [22]	train-rmse:7.23244	eval-rmse:7.37074
# [23]	train-rmse:7.17571	eval-rmse:7.32138
# [24]	train-rmse:7.12584	eval-rmse:7.27666
# [25]	train-rmse:7.0835	eval-rmse:7.23863
# [26]	train-rmse:7.04572	eval-rmse:7.20803
# [27]	train-rmse:7.01281	eval-rmse:7.19074
# [28]	train-rmse:6.983	eval-rmse:7.16883
# [29]	train-rmse:6.95776	eval-rmse:7.14248
# [30]	train-rmse:6.93564	eval-rmse:7.11822
# [31]	train-rmse:6.91512	eval-rmse:7.09999
# [32]	train-rmse:6.89668	eval-rmse:7.08579
# [33]	train-rmse:6.88132	eval-rmse:7.06472
# [34]	train-rmse:6.86732	eval-rmse:7.05093
# [35]	train-rmse:6.85383	eval-rmse:7.03991
# [36]	train-rmse:6.84242	eval-rmse:7.02507
# [37]	train-rmse:6.83205	eval-rmse:7.01558
# [38]	train-rmse:6.82307	eval-rmse:7.00538
# [39]	train-rmse:6.8145	eval-rmse:6.99346
# [40]	train-rmse:6.80736	eval-rmse:6.98706
# [41]	train-rmse:6.80046	eval-rmse:6.98378
# [42]	train-rmse:6.7947	eval-rmse:6.97753
# [43]	train-rmse:6.78903	eval-rmse:6.97245
# [44]	train-rmse:6.78376	eval-rmse:6.96872
# [45]	train-rmse:6.77883	eval-rmse:6.96768
# [46]	train-rmse:6.77414	eval-rmse:6.96387
# [47]	train-rmse:6.77049	eval-rmse:6.95772
# [48]	train-rmse:6.76633	eval-rmse:6.95685
# [49]	train-rmse:6.7617	eval-rmse:6.94705
# [50]	train-rmse:6.75839	eval-rmse:6.94568
# [51]	train-rmse:6.75367	eval-rmse:6.93652
# [52]	train-rmse:6.75002	eval-rmse:6.92975
# [53]	train-rmse:6.74742	eval-rmse:6.93114
# [54]	train-rmse:6.74464	eval-rmse:6.93547
# [55]	train-rmse:6.74177	eval-rmse:6.93272
# [56]	train-rmse:6.73887	eval-rmse:6.92983
# [57]	train-rmse:6.73652	eval-rmse:6.92549
# [58]	train-rmse:6.73385	eval-rmse:6.91988
# [59]	train-rmse:6.73172	eval-rmse:6.91981
# [60]	train-rmse:6.73018	eval-rmse:6.91774
# [61]	train-rmse:6.72726	eval-rmse:6.92251
# [62]	train-rmse:6.72439	eval-rmse:6.91787
# [63]	train-rmse:6.72155	eval-rmse:6.91422
# [64]	train-rmse:6.71871	eval-rmse:6.91195
# [65]	train-rmse:6.71634	eval-rmse:6.91527
# [66]	train-rmse:6.71393	eval-rmse:6.91925
# [67]	train-rmse:6.71199	eval-rmse:6.91794
# [68]	train-rmse:6.71073	eval-rmse:6.91523
# [69]	train-rmse:6.7086	eval-rmse:6.91922
# [70]	train-rmse:6.70532	eval-rmse:6.92744
# [71]	train-rmse:6.70361	eval-rmse:6.93117
# [72]	train-rmse:6.70147	eval-rmse:6.93576
# [73]	train-rmse:6.69982	eval-rmse:6.9355
# [74]	train-rmse:6.69803	eval-rmse:6.93303
# [75]	train-rmse:6.69676	eval-rmse:6.93163
# [76]	train-rmse:6.69506	eval-rmse:6.93406
# [77]	train-rmse:6.69292	eval-rmse:6.93364
# [78]	train-rmse:6.6885	eval-rmse:6.93882
# [79]	train-rmse:6.68599	eval-rmse:6.93859
# [80]	train-rmse:6.68407	eval-rmse:6.93812
# [81]	train-rmse:6.68212	eval-rmse:6.9365
# [82]	train-rmse:6.6795	eval-rmse:6.93881
# [83]	train-rmse:6.67717	eval-rmse:6.94569
# [84]	train-rmse:6.6758	eval-rmse:6.94951
# [85]	train-rmse:6.67307	eval-rmse:6.94648
# [86]	train-rmse:6.67078	eval-rmse:6.94867
# [87]	train-rmse:6.6694	eval-rmse:6.94634
# [88]	train-rmse:6.66715	eval-rmse:6.94314
# [89]	train-rmse:6.66574	eval-rmse:6.94897
# [90]	train-rmse:6.66515	eval-rmse:6.94807
# [91]	train-rmse:6.66117	eval-rmse:6.94924
# [92]	train-rmse:6.66014	eval-rmse:6.94647
# [93]	train-rmse:6.65898	eval-rmse:6.94532
# [94]	train-rmse:6.65814	eval-rmse:6.94336
# [95]	train-rmse:6.65514	eval-rmse:6.94153
# [96]	train-rmse:6.65328	eval-rmse:6.94026
# [97]	train-rmse:6.65095	eval-rmse:6.93774
# [98]	train-rmse:6.64874	eval-rmse:6.93631
# [99]	train-rmse:6.64688	eval-rmse:6.94555
# [100]	train-rmse:6.6458	eval-rmse:6.9498
# [101]	train-rmse:6.64481	eval-rmse:6.94951
# [102]	train-rmse:6.64213	eval-rmse:6.9464
# [103]	train-rmse:6.64037	eval-rmse:6.94573
# [104]	train-rmse:6.639	eval-rmse:6.94782
# [105]	train-rmse:6.63707	eval-rmse:6.94363
# [106]	train-rmse:6.63604	eval-rmse:6.94206
# [107]	train-rmse:6.63378	eval-rmse:6.94014
# [108]	train-rmse:6.63183	eval-rmse:6.94349
# [109]	train-rmse:6.62891	eval-rmse:6.94692
# [110]	train-rmse:6.62723	eval-rmse:6.94633

# %%
draw_loss(evals_result)
draw_preds(model, d_val, df_val_Y, target, 'test1')
draw_feat_importances(model)

# %% [markdown]
# - テスト２：~2019-12-11を学習して2019-12-12~2019-12-18一週間を予測

# %%
# データの読込と前処理
in_dir = f'../data/two_years_each/test_2/{task}'
df_train_X, df_train_Y, df_val_X, df_val_Y = read_data(in_dir, target)

# feature selection
#df_train_X, df_val_X = df_train_X[fi[:30]], df_val_X[fi[:30]]

# xgboost のデータ構造に転換
d_train_sales, d_val_sales, d_val = mtx_trans(target, df_train_X, df_train_Y, df_val_X, df_val_Y)

# %%
# バリデーションにおいて最適化されたパラメータで学習
model, evals_result = train2(d_train_sales, d_val_sales, params, best_iter=best_iter, esr=None)
# Out:
# [0]	train-rmse:14.0259	eval-rmse:12.8019
# [1]	train-rmse:13.2553	eval-rmse:12.157
# [2]	train-rmse:12.5599	eval-rmse:11.5882
# [3]	train-rmse:11.9286	eval-rmse:11.0729
# [4]	train-rmse:11.3592	eval-rmse:10.6194
# [5]	train-rmse:10.8445	eval-rmse:10.2267
# [6]	train-rmse:10.3817	eval-rmse:9.84053
# [7]	train-rmse:9.96602	eval-rmse:9.50779
# [8]	train-rmse:9.59477	eval-rmse:9.22516
# [9]	train-rmse:9.26139	eval-rmse:8.9587
# [10]	train-rmse:8.9667	eval-rmse:8.71811
# [11]	train-rmse:8.7051	eval-rmse:8.5178
# [12]	train-rmse:8.47193	eval-rmse:8.32988
# [13]	train-rmse:8.26668	eval-rmse:8.1737
# [14]	train-rmse:8.08547	eval-rmse:8.01374
# [15]	train-rmse:7.92449	eval-rmse:7.86755
# [16]	train-rmse:7.78358	eval-rmse:7.73972
# [17]	train-rmse:7.65965	eval-rmse:7.63375
# [18]	train-rmse:7.55082	eval-rmse:7.53374
# [19]	train-rmse:7.45531	eval-rmse:7.45303
# [20]	train-rmse:7.37358	eval-rmse:7.37896
# [21]	train-rmse:7.29926	eval-rmse:7.31801
# [22]	train-rmse:7.23679	eval-rmse:7.26321
# [23]	train-rmse:7.1807	eval-rmse:7.20726
# [24]	train-rmse:7.1315	eval-rmse:7.15923
# [25]	train-rmse:7.08962	eval-rmse:7.12661
# [26]	train-rmse:7.05206	eval-rmse:7.09742
# [27]	train-rmse:7.01898	eval-rmse:7.06809
# [28]	train-rmse:6.98969	eval-rmse:7.03785
# [29]	train-rmse:6.96382	eval-rmse:7.00435
# [30]	train-rmse:6.94206	eval-rmse:6.98155
# [31]	train-rmse:6.92276	eval-rmse:6.95986
# [32]	train-rmse:6.90556	eval-rmse:6.94521
# [33]	train-rmse:6.88934	eval-rmse:6.93333
# [34]	train-rmse:6.87524	eval-rmse:6.9222
# [35]	train-rmse:6.86157	eval-rmse:6.90666
# [36]	train-rmse:6.85	eval-rmse:6.88933
# [37]	train-rmse:6.83992	eval-rmse:6.87442
# [38]	train-rmse:6.83066	eval-rmse:6.86161
# [39]	train-rmse:6.82258	eval-rmse:6.85081
# [40]	train-rmse:6.81531	eval-rmse:6.83901
# [41]	train-rmse:6.80833	eval-rmse:6.82885
# [42]	train-rmse:6.80232	eval-rmse:6.81582
# [43]	train-rmse:6.79669	eval-rmse:6.80423
# [44]	train-rmse:6.79123	eval-rmse:6.78979
# [45]	train-rmse:6.78513	eval-rmse:6.78474
# [46]	train-rmse:6.78063	eval-rmse:6.77847
# [47]	train-rmse:6.77601	eval-rmse:6.77412
# [48]	train-rmse:6.77167	eval-rmse:6.76652
# [49]	train-rmse:6.76684	eval-rmse:6.75789
# [50]	train-rmse:6.76373	eval-rmse:6.75446
# [51]	train-rmse:6.76003	eval-rmse:6.75345
# [52]	train-rmse:6.75699	eval-rmse:6.7471
# [53]	train-rmse:6.75365	eval-rmse:6.74114
# [54]	train-rmse:6.75073	eval-rmse:6.7395
# [55]	train-rmse:6.74795	eval-rmse:6.73689
# [56]	train-rmse:6.74458	eval-rmse:6.7308
# [57]	train-rmse:6.74088	eval-rmse:6.72207
# [58]	train-rmse:6.73785	eval-rmse:6.71392
# [59]	train-rmse:6.73585	eval-rmse:6.7117
# [60]	train-rmse:6.73366	eval-rmse:6.7131
# [61]	train-rmse:6.73188	eval-rmse:6.71106
# [62]	train-rmse:6.72958	eval-rmse:6.70958
# [63]	train-rmse:6.72734	eval-rmse:6.70815
# [64]	train-rmse:6.72536	eval-rmse:6.71414
# [65]	train-rmse:6.72315	eval-rmse:6.72215
# [66]	train-rmse:6.72033	eval-rmse:6.71486
# [67]	train-rmse:6.71864	eval-rmse:6.71128
# [68]	train-rmse:6.71582	eval-rmse:6.70948
# [69]	train-rmse:6.71297	eval-rmse:6.70346
# [70]	train-rmse:6.71151	eval-rmse:6.69796
# [71]	train-rmse:6.71029	eval-rmse:6.69381
# [72]	train-rmse:6.70813	eval-rmse:6.69232
# [73]	train-rmse:6.70682	eval-rmse:6.69207
# [74]	train-rmse:6.70499	eval-rmse:6.69284
# [75]	train-rmse:6.70159	eval-rmse:6.6873
# [76]	train-rmse:6.69921	eval-rmse:6.68693
# [77]	train-rmse:6.69738	eval-rmse:6.68876
# [78]	train-rmse:6.69569	eval-rmse:6.68801
# [79]	train-rmse:6.69422	eval-rmse:6.69202
# [80]	train-rmse:6.69235	eval-rmse:6.6964
# [81]	train-rmse:6.68799	eval-rmse:6.69787
# [82]	train-rmse:6.68677	eval-rmse:6.69769
# [83]	train-rmse:6.6834	eval-rmse:6.69541
# [84]	train-rmse:6.68048	eval-rmse:6.69505
# [85]	train-rmse:6.67942	eval-rmse:6.69392
# [86]	train-rmse:6.6785	eval-rmse:6.69238
# [87]	train-rmse:6.67696	eval-rmse:6.69145
# [88]	train-rmse:6.67478	eval-rmse:6.69364
# [89]	train-rmse:6.67305	eval-rmse:6.69487
# [90]	train-rmse:6.6722	eval-rmse:6.69564
# [91]	train-rmse:6.67172	eval-rmse:6.69552
# [92]	train-rmse:6.66796	eval-rmse:6.69688
# [93]	train-rmse:6.66576	eval-rmse:6.69363
# [94]	train-rmse:6.66407	eval-rmse:6.69509
# [95]	train-rmse:6.66208	eval-rmse:6.68828
# [96]	train-rmse:6.65936	eval-rmse:6.68893
# [97]	train-rmse:6.65858	eval-rmse:6.68971
# [98]	train-rmse:6.65636	eval-rmse:6.69031
# [99]	train-rmse:6.65454	eval-rmse:6.68722
# [100]	train-rmse:6.65163	eval-rmse:6.69428
# [101]	train-rmse:6.6492	eval-rmse:6.69203
# [102]	train-rmse:6.64732	eval-rmse:6.68609
# [103]	train-rmse:6.64598	eval-rmse:6.68567
# [104]	train-rmse:6.64488	eval-rmse:6.68409
# [105]	train-rmse:6.64226	eval-rmse:6.68738
# [106]	train-rmse:6.64108	eval-rmse:6.68745
# [107]	train-rmse:6.63998	eval-rmse:6.68342
# [108]	train-rmse:6.63724	eval-rmse:6.68539
# [109]	train-rmse:6.63487	eval-rmse:6.68423
# [110]	train-rmse:6.63273	eval-rmse:6.68362

# %%
draw_loss(evals_result)
draw_preds(model, d_val, df_val_Y, target, 'test2')
draw_feat_importances(model)

# %%
fi = get_feat_importances(model)
len(fi)
# Out:
# 99
