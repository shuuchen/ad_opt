# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 生データの取得
# - 漏れを0で埋める

# %%
def read_raw_data(f_path):
    df = pd.read_excel(f_path, header=0, index_col=0)
    df = df.sort_index()
    df.fillna(0, inplace=True)
    return df

# %% [markdown]
# ### データの前処理
# - 広告コード抽出
# - 広告コード情報のコラム（定数コラム）を削除
# - Salesの合計を計算
# - 一週間の移動合計を取得

# %%
def _sales_sum(row):
    return sum(v for i, v in row.items() if 'Sales' in i)

def preprocess_raw_data(df):
    
    # Sales項を合計
    df['Sales'] = df.apply(lambda x: _sales_sum(x), axis=1)
    
    # 七日間の移動合計
    df['SalesSum'] = df['Sales'].rolling('7D').sum()
    df['ImpressionsSum'] = df['Impressions'].rolling('7D').sum()
    df['ClicksSum'] = df['Clicks'].rolling('7D').sum()
    df['CostSum'] = df['Cost'].rolling('7D').sum()
    
    
    code = {}
    for c in ['MarketId', 'AdvertiserId', 'CampaignId', 'CategoryId']:
        code[c] = df.iloc[0][c]

        
    df_x = df.drop(columns=['Market', 'MarketId', 'AdvertiserId', 'AdvertiserName', 
                          'CampaignId', 'CampaignName', 'CategoryId', 'CategoryName'])

    return df_x, df, code

# %% [markdown]
# ### 学習データ生成のアルゴリズム
# - 現在日から遡る７日分のデータから一週間後を予測
# - 現在日から一週間を間隔に遡る５週間分のデータから一週間後を予測

# %%
def create_train_data_consistent(df_x, df_y):
    X, Y = [], []
    for i, r in df_x.iterrows():
        if all(i + pd.DateOffset(d) in df_x.index and df_x.loc[i + pd.DateOffset(d)]['CpcBid'] > 0
               for d in [0,1,2,3,4,5,6,13]):
            
            x = pd.concat([df_x.loc[i + pd.DateOffset(d)].rename(lambda x: f'{x}_{6-d}') 
                           for d in range(6, -1, -1)])
            y = df_y.loc[i + pd.DateOffset(13)]
            
            x.name = i + pd.DateOffset(6)
            x.loc['CpcBid_Y'] = y.loc['CpcBid']
            
            X += [x]
            Y += [y]
    
    if not X:
        return None, None
    
    df_X = pd.concat(X, axis=1, keys=[x.name for x in X]).T
    df_Y = pd.concat(Y, axis=1, keys=[y.name for y in Y]).T
    
    '''
    df_Y = df_Y[['Market', 'AdvertiserName', 'CampaignName', 'CategoryName', 
                 'SalesRent', 'SalesRyutsu', 'SalesSck', 'SalesMansionBkn', 
                 'SalesMansionKen', 'SalesKodateBkn', 'SalesKodateKen', 
                 'Sales', 'Impressions', 'Clicks', 'Cost',
                 'SalesSum', 'ImpressionsSum', 'ClicksSum', 'CostSum',
                ]]
    '''
    return df_X, df_Y

# %%
def create_train_data_skip(df_x, df_y):
    X, Y = [], []
    for i, r in df_x.iterrows():
        if all(i + pd.DateOffset(d) in df_x.index and df_x.loc[i + pd.DateOffset(d)]['CpcBid'] > 0
               for d in range(0, 36, 7)):
            
            x = pd.concat([df_x.loc[i + pd.DateOffset(d)].rename(lambda x: f'{x}_{(28-d)//7}') 
                           for d in range(28, -1, -7)])
            y = df_y.loc[i + pd.DateOffset(35)]
            
            x.name = i + pd.DateOffset(28)
            x.loc['CpcBid_Y'] = y.loc['CpcBid']
            
            X += [x]
            Y += [y]
    
    if not X:
        return None, None
    
    df_X = pd.concat(X, axis=1, keys=[x.name for x in X]).T
    df_Y = pd.concat(Y, axis=1, keys=[y.name for y in Y]).T
    '''
    df_Y = df_Y[['Market', 'AdvertiserName', 'CampaignName', 'CategoryName', 
                 'SalesRent', 'SalesRyutsu', 'SalesSck', 'SalesMansionBkn', 
                 'SalesMansionKen', 'SalesKodateBkn', 'SalesKodateKen', 
                 'Sales', 'Impressions', 'Clicks', 'Cost',
                 'SalesSum', 'ImpressionsSum', 'ClicksSum', 'CostSum',
                ]]
    '''
    return df_X, df_Y

# %% [markdown]
# ### 学習データを作成

# %%
in_dir = './data/two_years_each/data/'
out_dir_cons = './data/two_years_each/data_consistent/'
out_dir_skip = './data/two_years_each/data_skip/'
for fi, f in enumerate(os.listdir(in_dir)):
    #if fi > 0: break
    
    print('-' * 25)
    print(f)
    
    f_name = os.path.splitext(f)[0]
    f_path = os.path.join(in_dir, f)
    
    df = read_raw_data(f_path)
    df_x, df_y, code = preprocess_raw_data(df)
    print(code)
    
    df_X, df_Y = create_train_data_consistent(df_x, df_y)
    if df_X is not None:
        for i, (k, v) in enumerate(code.items()): df_X.insert(loc=i, column=k, value=v)
        df_X.to_excel(os.path.join(out_dir_cons, f'{f_name}_X.xlsx'))
        df_Y.to_excel(os.path.join(out_dir_cons, f'{f_name}_Y.xlsx'))
        print(f'Number of consistent train data: {len(df_X)}')

    df_X, df_Y = create_train_data_skip(df_x, df_y)
    if df_X is not None:
        for i, (k, v) in enumerate(code.items()): df_X.insert(loc=i, column=k, value=v)
        df_X.to_excel(os.path.join(out_dir_skip, f'{f_name}_X.xlsx'))
        df_Y.to_excel(os.path.join(out_dir_skip, f'{f_name}_Y.xlsx'))
        print(f'Number of skip train data: {len(df_X)}')
    
    #break
# Out:
# -------------------------
# 0_2914_106510_122129909_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106510, 'CategoryId': 122129909}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 2_3616_106515_150581531_29.xlsx
# {'MarketId': 2, 'AdvertiserId': 3616, 'CampaignId': 106515, 'CategoryId': 150581531}
# Number of consistent train data: 2
# -------------------------
# 3_2773_157502_587672534_94.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 157502, 'CategoryId': 587672534}
# -------------------------
# 1_3051_188627_1_13.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 188627, 'CategoryId': 1}
# -------------------------
# 0_2914_106509_1884256507_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106509, 'CategoryId': 1884256507}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 0_2914_106510_1884256507_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106510, 'CategoryId': 1884256507}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 0_2914_106509_739735262_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106509, 'CategoryId': 739735262}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 3_2773_106513_-1_620.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 106513, 'CategoryId': -1}
# -------------------------
# 4_22864_106511_563052188_688.xlsx
# {'MarketId': 4, 'AdvertiserId': 22864, 'CampaignId': 106511, 'CategoryId': 563052188}
# Number of consistent train data: 662
# Number of skip train data: 618
# -------------------------
# 3_2773_106513_1652289276_699.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 106513, 'CategoryId': 1652289276}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 2_15912_106516_710927542_699.xlsx
# {'MarketId': 2, 'AdvertiserId': 15912, 'CampaignId': 106516, 'CategoryId': 710927542}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 2_3616_106515_1251677358_26.xlsx
# {'MarketId': 2, 'AdvertiserId': 3616, 'CampaignId': 106515, 'CategoryId': 1251677358}
# Number of consistent train data: 1
# -------------------------
# 2_3616_106515_0_24.xlsx
# {'MarketId': 2, 'AdvertiserId': 3616, 'CampaignId': 106515, 'CategoryId': 0}
# -------------------------
# 3_2773_106513_477150441_699.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 106513, 'CategoryId': 477150441}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 2_15911_106512_0_699.xlsx
# {'MarketId': 2, 'AdvertiserId': 15911, 'CampaignId': 106512, 'CategoryId': 0}
# -------------------------
# 2_3616_106515_559598750_24.xlsx
# {'MarketId': 2, 'AdvertiserId': 3616, 'CampaignId': 106515, 'CategoryId': 559598750}
# Number of consistent train data: 1
# -------------------------
# 2_15911_106512_1930529710_693.xlsx
# {'MarketId': 2, 'AdvertiserId': 15911, 'CampaignId': 106512, 'CategoryId': 1930529710}
# Number of consistent train data: 680
# Number of skip train data: 658
# -------------------------
# 1_3051_105356_601694530_253.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 105356, 'CategoryId': 601694530}
# Number of consistent train data: 240
# Number of skip train data: 218
# -------------------------
# 4_22864_106511_768086752_687.xlsx
# {'MarketId': 4, 'AdvertiserId': 22864, 'CampaignId': 106511, 'CategoryId': 768086752}
# Number of consistent train data: 661
# Number of skip train data: 617
# -------------------------
# 2_15911_106512_1745346376_699.xlsx
# {'MarketId': 2, 'AdvertiserId': 15911, 'CampaignId': 106512, 'CategoryId': 1745346376}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 3_2773_157502_477150441_95.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 157502, 'CategoryId': 477150441}
# -------------------------
# 0_2914_106509_967178013_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106509, 'CategoryId': 967178013}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 3_2773_106513_2064083645_699.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 106513, 'CategoryId': 2064083645}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 1_3051_105355_307512344_698.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 105355, 'CategoryId': 307512344}
# Number of consistent train data: 679
# Number of skip train data: 662
# -------------------------
# 0_2914_106509_1363706990_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106509, 'CategoryId': 1363706990}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 0_2914_106510_0_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106510, 'CategoryId': 0}
# -------------------------
# 2_15911_106512_1119962470_699.xlsx
# {'MarketId': 2, 'AdvertiserId': 15911, 'CampaignId': 106512, 'CategoryId': 1119962470}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 1_3051_157505_782042272_93.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 157505, 'CategoryId': 782042272}
# -------------------------
# 3_2773_157502_647396435_94.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 157502, 'CategoryId': 647396435}
# -------------------------
# 0_2914_106510_1363706990_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106510, 'CategoryId': 1363706990}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 3_2773_157502_800963742_95.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 157502, 'CategoryId': 800963742}
# -------------------------
# 0_2914_106509_360278056_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106509, 'CategoryId': 360278056}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 3_2773_106513_357928842_699.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 106513, 'CategoryId': 357928842}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 2_3616_106515_2118878002_25.xlsx
# {'MarketId': 2, 'AdvertiserId': 3616, 'CampaignId': 106515, 'CategoryId': 2118878002}
# Number of consistent train data: 1
# -------------------------
# 4_22864_106511_14975341_687.xlsx
# {'MarketId': 4, 'AdvertiserId': 22864, 'CampaignId': 106511, 'CategoryId': 14975341}
# Number of consistent train data: 661
# Number of skip train data: 617
# -------------------------
# 1_3051_188627_0_48.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 188627, 'CategoryId': 0}
# -------------------------
# 1_3051_105356_0_254.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 105356, 'CategoryId': 0}
# -------------------------
# 3_2773_106513_307427601_699.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 106513, 'CategoryId': 307427601}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 2_3616_106515_537842849_23.xlsx
# {'MarketId': 2, 'AdvertiserId': 3616, 'CampaignId': 106515, 'CategoryId': 537842849}
# Number of consistent train data: 1
# -------------------------
# 0_2914_106509_0_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106509, 'CategoryId': 0}
# -------------------------
# 1_3051_105356_1838369041_252.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 105356, 'CategoryId': 1838369041}
# Number of consistent train data: 239
# Number of skip train data: 217
# -------------------------
# 3_2773_106513_1600325479_699.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 106513, 'CategoryId': 1600325479}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 0_2914_106509_1007561482_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106509, 'CategoryId': 1007561482}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 0_2914_106510_145781276_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106510, 'CategoryId': 145781276}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 0_2914_106509_1191599194_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106509, 'CategoryId': 1191599194}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 2_3616_106515_1403161255_27.xlsx
# {'MarketId': 2, 'AdvertiserId': 3616, 'CampaignId': 106515, 'CategoryId': 1403161255}
# Number of consistent train data: 2
# -------------------------
# 0_2914_106510_1191599194_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106510, 'CategoryId': 1191599194}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 4_22864_106511_1654090720_604.xlsx
# {'MarketId': 4, 'AdvertiserId': 22864, 'CampaignId': 106511, 'CategoryId': 1654090720}
# Number of consistent train data: 540
# Number of skip train data: 476
# -------------------------
# 1_3051_105355_739735262_698.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 105355, 'CategoryId': 739735262}
# Number of consistent train data: 679
# Number of skip train data: 662
# -------------------------
# 1_3051_105356_800963742_253.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 105356, 'CategoryId': 800963742}
# Number of consistent train data: 239
# Number of skip train data: 217
# -------------------------
# 4_22864_106511_1963222332_699.xlsx
# {'MarketId': 4, 'AdvertiserId': 22864, 'CampaignId': 106511, 'CategoryId': 1963222332}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 3_2773_106513_357413589_699.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 106513, 'CategoryId': 357413589}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 3_2773_157502_357928842_94.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 157502, 'CategoryId': 357928842}
# -------------------------
# 1_3051_105356_1419782967_252.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 105356, 'CategoryId': 1419782967}
# Number of consistent train data: 239
# Number of skip train data: 217
# -------------------------
# 0_2914_106510_1007561482_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106510, 'CategoryId': 1007561482}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 4_22864_106511_535750448_699.xlsx
# {'MarketId': 4, 'AdvertiserId': 22864, 'CampaignId': 106511, 'CategoryId': 535750448}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 1_3051_105355_1939770162_698.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 105355, 'CategoryId': 1939770162}
# Number of consistent train data: 679
# Number of skip train data: 662
# -------------------------
# 4_22864_106511_1466143889_687.xlsx
# {'MarketId': 4, 'AdvertiserId': 22864, 'CampaignId': 106511, 'CategoryId': 1466143889}
# Number of consistent train data: 661
# Number of skip train data: 617
# -------------------------
# 3_2773_157502_739735262_94.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 157502, 'CategoryId': 739735262}
# -------------------------
# 4_22864_106511_1415097530_688.xlsx
# {'MarketId': 4, 'AdvertiserId': 22864, 'CampaignId': 106511, 'CategoryId': 1415097530}
# Number of consistent train data: 661
# Number of skip train data: 618
# -------------------------
# 3_2773_157502_307427601_94.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 157502, 'CategoryId': 307427601}
# -------------------------
# 4_22864_106511_0_690.xlsx
# {'MarketId': 4, 'AdvertiserId': 22864, 'CampaignId': 106511, 'CategoryId': 0}
# -------------------------
# 2_3616_106515_1129747985_23.xlsx
# {'MarketId': 2, 'AdvertiserId': 3616, 'CampaignId': 106515, 'CategoryId': 1129747985}
# Number of consistent train data: 1
# -------------------------
# 3_2773_157502_874499868_99.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 157502, 'CategoryId':
xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 157502, 'CategoryId': 2044194994}
# -------------------------
# 0_2914_106509_-1_76.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106509, 'CategoryId': -1}
# -------------------------
# 0_2914_106509_501309237_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106509, 'CategoryId': 501309237}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 0_2914_106509_103157776_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106509, 'CategoryId': 103157776}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 1_3051_157505_307512344_93.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 157505, 'CategoryId': 307512344}
# -------------------------
# 3_2773_106513_785101548_699.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 106513, 'CategoryId': 785101548}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 3_2773_157502_123850463_95.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 157502, 'CategoryId': 123850463}
# -------------------------
# 3_2773_157502_-1_94.xlsx
# {'MarketId': 3, 'AdvertiserId': 2773, 'CampaignId': 157502, 'CategoryId': -1}
# -------------------------
# 0_2914_106510_1970606947_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106510, 'CategoryId': 1970606947}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 2_15912_106516_-1_78.xlsx
# {'MarketId': 2, 'AdvertiserId': 15912, 'CampaignId': 106516, 'CategoryId': -1}
# -------------------------
# 1_3051_157505_601694530_93.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 157505, 'CategoryId': 601694530}
# -------------------------
# 0_2914_106509_1970606947_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106509, 'CategoryId': 1970606947}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 1_3051_105355_800963742_698.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 105355, 'CategoryId': 800963742}
# Number of consistent train data: 679
# Number of skip train data: 662
# -------------------------
# 1_3051_157505_0_94.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 157505, 'CategoryId': 0}
# -------------------------
# 2_15912_106516_1981125160_699.xlsx
# {'MarketId': 2, 'AdvertiserId': 15912, 'CampaignId': 106516, 'CategoryId': 1981125160}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 2_15912_106516_2046868865_699.xlsx
# {'MarketId': 2, 'AdvertiserId': 15912, 'CampaignId': 106516, 'CategoryId': 2046868865}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 4_22864_106511_1728374149_695.xlsx
# {'MarketId': 4, 'AdvertiserId': 22864, 'CampaignId': 106511, 'CategoryId': 1728374149}
# Number of consistent train data: 668
# Number of skip train data: 645
# -------------------------
# 0_2914_106509_710057733_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106509, 'CategoryId': 710057733}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 2_3616_106515_335893072_25.xlsx
# {'MarketId': 2, 'AdvertiserId': 3616, 'CampaignId': 106515, 'CategoryId': 335893072}
# Number of consistent train data: 2
# -------------------------
# 1_3051_105356_1939770162_252.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 105356, 'CategoryId': 1939770162}
# Number of consistent train data: 239
# Number of skip train data: 217
# -------------------------
# 0_2914_106510_393836642_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106510, 'CategoryId': 393836642}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 1_3051_157505_1007561482_93.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 157505, 'CategoryId': 1007561482}
# -------------------------
# 0_2914_106510_647500945_699.xlsx
# {'MarketId': 0, 'AdvertiserId': 2914, 'CampaignId': 106510, 'CategoryId': 647500945}
# Number of consistent train data: 686
# Number of skip train data: 664
# -------------------------
# 1_3051_157505_1884256507_93.xlsx
# {'MarketId': 1, 'AdvertiserId': 3051, 'CampaignId': 157505, 'CategoryId': 1884256507}

# %% [markdown]
# ### テストデータを分割
# - test_1: 2019/12/4までを学習して2019/12/5~2019/12/11の予測
# - test_2: 2019/12/11までを学習して2019/12/12~2019/12/18の予測

# %%
def split(train_X_end, train_Y_end, \
          val_X_begin, val_Y_begin, \
          val_X_end, val_Y_end, \
          train_dir, output_dir, \
          in_dir='./data/two_years_each/data'):
    
    df_X_train_all, df_Y_train_all = [], []
    df_X_val_all, df_Y_val_all = [], []

    for i, f in enumerate(os.listdir(in_dir)):

        #if i > 2: break
        f_name = os.path.splitext(f)[0]
        if not os.path.exists(os.path.join(train_dir, f'{f_name}_X.xlsx')):
            print(f'not found: {f_name}')
            continue

        df_X = pd.read_excel(os.path.join(train_dir, f'{f_name}_X.xlsx'), header=0, index_col=0)
        df_Y = pd.read_excel(os.path.join(train_dir, f'{f_name}_Y.xlsx'), header=0, index_col=0)

        assert len(df_X) == len(df_Y), '[Error] length of X and Y do not match !'

        df_X_train, df_X_val = df_X[:train_X_end], df_X[val_X_begin:val_X_end]
        df_Y_train, df_Y_val = df_Y[:train_Y_end], df_Y[val_Y_begin:val_Y_end]

        assert len(df_X_train) == len(df_Y_train) and len(df_X_val) == len(df_Y_val), '[Error] length of X and Y do not match !'

        df_X_train_all += [df_X_train]
        df_Y_train_all += [df_Y_train]
        df_X_val_all += [df_X_val]
        df_Y_val_all += [df_Y_val]

        #break

    df_X_train_all, df_Y_train_all = pd.concat(df_X_train_all), pd.concat(df_Y_train_all)
    df_X_val_all, df_Y_val_all = pd.concat(df_X_val_all), pd.concat(df_Y_val_all)

    df_X_train_all.to_excel(os.path.join(output_dir, 'train_X.xlsx'))
    df_Y_train_all.to_excel(os.path.join(output_dir, 'train_Y.xlsx'))
    df_X_val_all.to_excel(os.path.join(output_dir, 'val_X.xlsx'))
    df_Y_val_all.to_excel(os.path.join(output_dir, 'val_Y.xlsx'))

# %%
# test_1
train_X_end, train_Y_end = '2019-11-27', '2019-12-04'
val_X_begin, val_Y_begin = '2019-11-28', '2019-12-05'
val_X_end, val_Y_end = '2019-12-04', '2019-12-11'

for task in ['skip', 'consistent']:
    train_dir = f'./data/two_years_each/data_{task}/'
    output_dir = f'./data/two_years_each/test_1/{task}/'

    split(train_X_end, train_Y_end, 
          val_X_begin, val_Y_begin,
          val_X_end, val_Y_end,
          train_dir, output_dir)
# Out:
# not found: 2_3616_106515_150581531_29
# not found: 3_2773_157502_587672534_94
# not found: 1_3051_188627_1_13
# not found: 3_2773_106513_-1_620
# not found: 2_3616_106515_1251677358_26
# not found: 2_3616_106515_0_24
# not found: 2_15911_106512_0_699
# not found: 2_3616_106515_559598750_24
# not found: 3_2773_157502_477150441_95
# not found: 0_2914_106510_0_699
# not found: 1_3051_157505_782042272_93
# not found: 3_2773_157502_647396435_94
# not found: 3_2773_157502_800963742_95
# not found: 2_3616_106515_2118878002_25
# not found: 1_3051_188627_0_48
# not found: 1_3051_105356_0_254
# not found: 2_3616_106515_537842849_23
# not found: 0_2914_106509_0_699
# not found: 2_3616_106515_1403161255_27
# not found: 3_2773_157502_357928842_94
# not found: 3_2773_157502_739735262_94
# not found: 3_2773_157502_307427601_94
# not found: 4_22864_106511_0_690
# not found: 2_3616_106515_1129747985_23
# not found: 3_2773_157502_874499868_99
# not found: 1_3051_188627_-1_25
# not found: 1_3051_105355_-1_52
# not found: 3_2773_157502_1881376968_97
# not found: 1_3051_157505_845043661_93
# not found: 1_3051_188626_2_15
# not found: 1_3051_157505_739735262_93
# not found: 2_3616_106515_347955945_24
# not found: 3_2773_157502_1884256507_94
# not found: 1_3051_105355_0_698
# not found: 3_2773_157502_1714381509_93
# not found: 3_2773_157502_785101548_96
# not found: 2_3616_106515_1489178521_24
# not found: 3_2773_157502_1007102019_94
# not found: 1_3051_157505_800963742_93
# not found: 1_3051_157505_1939770162_93
# not found: 1_3051_157505_587705592_93
