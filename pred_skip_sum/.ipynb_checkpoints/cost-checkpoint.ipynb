# %%
import sys
sys.path.append('../')
from functions import *
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### データ読込

# %%
task, target = 'skip', 'CostSum'
in_dir = f'../data/two_years_each/val/{task}'
df_train_X, df_train_Y, df_val_X, df_val_Y = read_data(in_dir, target)
# Out:
# ../functions.py:28: FutureWarning: `weekday_name` is deprecated and will be removed in a future version. Use `day_name` instead
#   return m[x.name.weekday_name]
# ../functions.py:24: FutureWarning: `weekday_name` is deprecated and will be removed in a future version. Use `day_name` instead
#   return 1 if x.name.weekday_name in ['Saturday', 'Sunday'] else 0

# %% [markdown]
# ### 目的変数の分布

# %%
sns.distplot(np.log(df_train_Y[target] + 0.00000001))
plt.plot()
# Out:
# []

# %% [markdown]
# ### データ構造転換

# %%
d_train_sales, d_val_sales, d_val = mtx_trans(target, df_train_X, df_train_Y, df_val_X, df_val_Y)
# Out:
# /Users/dushu/opt/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /Users/dushu/opt/anaconda3/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %% [markdown]
# ### パラメータのベイズ最適化

# %%
#params = optimize()
#params

# %% [markdown]
# ### xgboost のバリデーションモデルを作成
# - 最適化されたパラメータでモデルを作成

# %%
params = {'alpha': 9.884316230116986e-08,
 'colsample_bytree': 0.9500000000000001,
 'eta': 0.30000000000000004,
 'gamma': 7.075270751580355e-07,
 'lambda': 0.0029099793175984797,
 'max_depth': 5,
 'min_child_weight': 2.311509085786557,
 'n_estimators': 457.0,
 'subsample': 0.8500000000000001}

model, evals_result = train2(d_train_sales, d_val_sales, params)
best_iter = model.best_iteration
# Out:
# [0]	train-rmse:6.38117	eval-rmse:6.59326
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:4.57053	eval-rmse:4.64959
# [2]	train-rmse:3.33576	eval-rmse:3.29866
# [3]	train-rmse:2.51411	eval-rmse:2.35082
# [4]	train-rmse:1.9815	eval-rmse:1.70883
# [5]	train-rmse:1.65209	eval-rmse:1.26384
# [6]	train-rmse:1.45555	eval-rmse:0.968581
# [7]	train-rmse:1.34481	eval-rmse:0.783493
# [8]	train-rmse:1.27023	eval-rmse:0.664456
# [9]	train-rmse:1.2272	eval-rmse:0.597457
# [10]	train-rmse:1.20445	eval-rmse:0.555729
# [11]	train-rmse:1.17374	eval-rmse:0.536172
# [12]	train-rmse:1.14501	eval-rmse:0.523823
# [13]	train-rmse:1.12787	eval-rmse:0.516168
# [14]	train-rmse:1.11169	eval-rmse:0.514545
# [15]	train-rmse:1.10171	eval-rmse:0.51269
# [16]	train-rmse:1.08137	eval-rmse:0.510912
# [17]	train-rmse:1.07363	eval-rmse:0.510823
# [18]	train-rmse:1.06757	eval-rmse:0.509572
# [19]	train-rmse:1.05299	eval-rmse:0.505949
# [20]	train-rmse:1.04716	eval-rmse:0.504212
# [21]	train-rmse:1.03535	eval-rmse:0.503701
# [22]	train-rmse:1.01826	eval-rmse:0.503429
# [23]	train-rmse:1.01365	eval-rmse:0.503436
# [24]	train-rmse:0.999139	eval-rmse:0.502393
# [25]	train-rmse:0.989893	eval-rmse:0.498754
# [26]	train-rmse:0.983191	eval-rmse:0.498744
# [27]	train-rmse:0.972596	eval-rmse:0.498589
# [28]	train-rmse:0.964847	eval-rmse:0.498356
# [29]	train-rmse:0.962054	eval-rmse:0.496863
# [30]	train-rmse:0.956272	eval-rmse:0.497327
# [31]	train-rmse:0.945798	eval-rmse:0.494609
# [32]	train-rmse:0.939727	eval-rmse:0.49222
# [33]	train-rmse:0.935489	eval-rmse:0.493189
# [34]	train-rmse:0.925377	eval-rmse:0.494873
# [35]	train-rmse:0.919151	eval-rmse:0.495591
# [36]	train-rmse:0.912114	eval-rmse:0.495533
# [37]	train-rmse:0.906776	eval-rmse:0.496766
# [38]	train-rmse:0.903323	eval-rmse:0.496994
# [39]	train-rmse:0.893851	eval-rmse:0.499145
# [40]	train-rmse:0.889421	eval-rmse:0.497218
# [41]	train-rmse:0.882275	eval-rmse:0.497047
# [42]	train-rmse:0.877653	eval-rmse:0.497028
# [43]	train-rmse:0.869147	eval-rmse:0.495637
# [44]	train-rmse:0.86352	eval-rmse:0.514133
# [45]	train-rmse:0.856894	eval-rmse:0.514407
# [46]	train-rmse:0.853333	eval-rmse:0.513363
# [47]	train-rmse:0.845843	eval-rmse:0.512381
# [48]	train-rmse:0.840003	eval-rmse:0.512287
# [49]	train-rmse:0.837749	eval-rmse:0.512217
# [50]	train-rmse:0.834337	eval-rmse:0.511616
# [51]	train-rmse:0.831374	eval-rmse:0.511828
# [52]	train-rmse:0.818551	eval-rmse:0.510615
# Stopping. Best iteration:
# [32]	train-rmse:0.939727	eval-rmse:0.49222

# %% [markdown]
# ### 損失関数の曲線

# %%
def draw_loss(evals_result):
    train_metric = evals_result['train']['rmse']
    plt.plot(train_metric, label='train rmse')
    eval_metric = evals_result['eval']['rmse']
    plt.plot(eval_metric, label='eval rmse')
    plt.grid()
    plt.legend()
    plt.title('loss curves')
    plt.xlabel('rounds')
    plt.ylabel('rmse')
    plt.show()
draw_loss(evals_result)

# %% [markdown]
# ### バリデーション結果と実測値

# %%
def draw_preds(model, d_val, df_val_Y, target, pred_type='validation'):
    d_pred_log = model.predict(d_val)
    d_pred = np.exp(d_pred_log)
    
    df_val_Y[f'{target}_pred'] = d_pred
    df_val_Y.to_excel(f'./output/{target}_{pred_type}.xlsx')

    plt.figure(figsize=(15,5))
    plt.plot(df_val_Y[target].values, label='real')
    plt.plot(d_pred, label='pred')
    plt.title('real and predicted values')
    plt.legend()
    plt.grid()
    plt.show()
draw_preds(model, d_val, df_val_Y, target)

# %% [markdown]
# ### 特徴量の寄与度

# %%
def draw_feat_importances(model):
    _, ax = plt.subplots(figsize=(15,30))
    xgb.plot_importance(model, ax=ax, importance_type='gain')
    plt.show()
draw_feat_importances(model)

# %%
fi = get_feat_importances(model)

# %% [markdown]
# ### 最適化されたパラメータで予測モデルを作成
# - テスト１：~2019/12/4を学習して2019/12/5~2019/12/11一週間を予測

# %%
# データの読込と前処理
in_dir = f'../data/two_years_each/test_1/{task}'
df_train_X, df_train_Y, df_val_X, df_val_Y = read_data(in_dir, target)

# xgboost のデータ構造に転換
d_train_sales, d_val_sales, d_val = mtx_trans(target, df_train_X, df_train_Y, df_val_X, df_val_Y)

# %%
# バリデーションにおいて最適化されたパラメータで学習
model, evals_result = train2(d_train_sales, d_val_sales, params, best_iter=best_iter, esr=None)
# Out:
# [0]	train-rmse:6.38944	eval-rmse:6.85239
# [1]	train-rmse:4.57337	eval-rmse:4.86161
# [2]	train-rmse:3.33192	eval-rmse:3.47594
# [3]	train-rmse:2.5048	eval-rmse:2.50497
# [4]	train-rmse:1.96734	eval-rmse:1.8301
# [5]	train-rmse:1.62749	eval-rmse:1.38269
# [6]	train-rmse:1.43012	eval-rmse:1.07026
# [7]	train-rmse:1.31039	eval-rmse:0.871459
# [8]	train-rmse:1.23781	eval-rmse:0.738792
# [9]	train-rmse:1.19447	eval-rmse:0.647099
# [10]	train-rmse:1.16809	eval-rmse:0.598288
# [11]	train-rmse:1.14806	eval-rmse:0.563875
# [12]	train-rmse:1.12881	eval-rmse:0.539877
# [13]	train-rmse:1.11134	eval-rmse:0.527388
# [14]	train-rmse:1.08316	eval-rmse:0.518824
# [15]	train-rmse:1.0702	eval-rmse:0.509935
# [16]	train-rmse:1.05477	eval-rmse:0.501249
# [17]	train-rmse:1.03431	eval-rmse:0.498984
# [18]	train-rmse:1.02352	eval-rmse:0.49746
# [19]	train-rmse:1.01575	eval-rmse:0.494277
# [20]	train-rmse:0.997983	eval-rmse:0.493203
# [21]	train-rmse:0.994414	eval-rmse:0.493877
# [22]	train-rmse:0.988937	eval-rmse:0.492285
# [23]	train-rmse:0.984434	eval-rmse:0.490725
# [24]	train-rmse:0.971425	eval-rmse:0.488359
# [25]	train-rmse:0.957456	eval-rmse:0.488522
# [26]	train-rmse:0.947635	eval-rmse:0.483819
# [27]	train-rmse:0.942057	eval-rmse:0.484984
# [28]	train-rmse:0.927948	eval-rmse:0.483406
# [29]	train-rmse:0.923739	eval-rmse:0.483748
# [30]	train-rmse:0.9186	eval-rmse:0.48365
# [31]	train-rmse:0.90725	eval-rmse:0.483611

# %%
draw_loss(evals_result)
draw_preds(model, d_val, df_val_Y, target, 'test1')
draw_feat_importances(model)

# %% [markdown]
# - テスト２：~2019-12-11を学習して2019-12-12~2019-12-18一週間を予測

# %%
# データの読込と前処理
in_dir = f'../data/two_years_each/test_2/{task}'
df_train_X, df_train_Y, df_val_X, df_val_Y = read_data(in_dir, target)

# xgboost のデータ構造に転換
d_train_sales, d_val_sales, d_val = mtx_trans(target, df_train_X, df_train_Y, df_val_X, df_val_Y)

# %%
# バリデーションにおいて最適化されたパラメータで学習
model, evals_result = train2(d_train_sales, d_val_sales, params, best_iter=best_iter, esr=None)
# Out:
# [0]	train-rmse:6.39358	eval-rmse:6.50591
# [1]	train-rmse:4.57569	eval-rmse:4.49868
# [2]	train-rmse:3.33417	eval-rmse:3.09749
# [3]	train-rmse:2.50195	eval-rmse:2.12526
# [4]	train-rmse:1.96497	eval-rmse:1.45671
# [5]	train-rmse:1.6298	eval-rmse:1.01042
# [6]	train-rmse:1.42858	eval-rmse:0.728263
# [7]	train-rmse:1.31372	eval-rmse:0.56495
# [8]	train-rmse:1.24293	eval-rmse:0.482973
# [9]	train-rmse:1.20408	eval-rmse:0.447346
# [10]	train-rmse:1.17421	eval-rmse:0.442668
# [11]	train-rmse:1.1379	eval-rmse:0.450566
# [12]	train-rmse:1.11825	eval-rmse:0.457814
# [13]	train-rmse:1.0998	eval-rmse:0.468103
# [14]	train-rmse:1.08259	eval-rmse:0.537754
# [15]	train-rmse:1.07142	eval-rmse:0.540551
# [16]	train-rmse:1.06056	eval-rmse:0.541945
# [17]	train-rmse:1.03847	eval-rmse:0.543751
# [18]	train-rmse:1.03046	eval-rmse:0.54497
# [19]	train-rmse:1.02552	eval-rmse:0.538734
# [20]	train-rmse:1.01405	eval-rmse:0.538247
# [21]	train-rmse:1.00969	eval-rmse:0.538211
# [22]	train-rmse:0.997903	eval-rmse:0.538965
# [23]	train-rmse:0.993988	eval-rmse:0.537627
# [24]	train-rmse:0.980505	eval-rmse:0.536427
# [25]	train-rmse:0.971144	eval-rmse:0.538147
# [26]	train-rmse:0.959299	eval-rmse:0.538131
# [27]	train-rmse:0.945751	eval-rmse:0.567181
# [28]	train-rmse:0.937435	eval-rmse:0.566448
# [29]	train-rmse:0.931731	eval-rmse:0.566666
# [30]	train-rmse:0.923344	eval-rmse:0.576728
# [31]	train-rmse:0.919107	eval-rmse:0.576737

# %%
draw_loss(evals_result)
draw_preds(model, d_val, df_val_Y, target, 'test2')
draw_feat_importances(model)
