# %%
import sys
sys.path.append('../')
from functions import *
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### データ読込

# %%
task, target = 'skip', 'SalesSum'
in_dir = f'../data/two_years_each/val/{task}'
df_train_X, df_train_Y, df_val_X, df_val_Y = read_data(in_dir, target)
# Out:
# ../functions.py:28: FutureWarning: `weekday_name` is deprecated and will be removed in a future version. Use `day_name` instead
#   return m[x.name.weekday_name]
# ../functions.py:24: FutureWarning: `weekday_name` is deprecated and will be removed in a future version. Use `day_name` instead
#   return 1 if x.name.weekday_name in ['Saturday', 'Sunday'] else 0

# %% [markdown]
# ### 目的変数の分布

# %%
sns.distplot(np.log(df_train_Y[target] + 0.00000001))
plt.plot()
# Out:
# []

# %% [markdown]
# ### データ構造転換

# %%
d_train_sales, d_val_sales, d_val = mtx_trans(target, df_train_X, df_train_Y, df_val_X, df_val_Y)
# Out:
# /Users/dushu/opt/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /Users/dushu/opt/anaconda3/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %% [markdown]
# ### パラメータのベイズ最適化

# %%
#params = optimize()
#params

# %% [markdown]
# ### xgboost のバリデーションモデルを作成
# - 最適化されたパラメータでモデルを作成

# %%
params = {'alpha': 8.276787331565617e-06,
 'colsample_bytree': 0.75,
 'eta': 0.07500000000000001,
 'gamma': 0.01649438786046292,
 'lambda': 0.22097300588062377,
 'max_depth': 5,
 'min_child_weight': 7.449328429538007,
 'n_estimators': 918.0,
 'subsample': 0.75}

model, evals_result = train2(d_train_sales, d_val_sales, params)
best_iter = model.best_iteration
# Out:
# [0]	train-rmse:14.037	eval-rmse:12.627
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:13.2326	eval-rmse:12.0129
# [2]	train-rmse:12.5058	eval-rmse:11.4605
# [3]	train-rmse:11.8455	eval-rmse:10.972
# [4]	train-rmse:11.2506	eval-rmse:10.5397
# [5]	train-rmse:10.7086	eval-rmse:10.1463
# [6]	train-rmse:10.2239	eval-rmse:9.79432
# [7]	train-rmse:9.78435	eval-rmse:9.48574
# [8]	train-rmse:9.38931	eval-rmse:9.2114
# [9]	train-rmse:9.03522	eval-rmse:8.96944
# [10]	train-rmse:8.7213	eval-rmse:8.75883
# [11]	train-rmse:8.44278	eval-rmse:8.58111
# [12]	train-rmse:8.19086	eval-rmse:8.41785
# [13]	train-rmse:7.96765	eval-rmse:8.27517
# [14]	train-rmse:7.77192	eval-rmse:8.14689
# [15]	train-rmse:7.5968	eval-rmse:8.03666
# [16]	train-rmse:7.44236	eval-rmse:7.92866
# [17]	train-rmse:7.30835	eval-rmse:7.84855
# [18]	train-rmse:7.1895	eval-rmse:7.7719
# [19]	train-rmse:7.08216	eval-rmse:7.71516
# [20]	train-rmse:6.98872	eval-rmse:7.66418
# [21]	train-rmse:6.90581	eval-rmse:7.62568
# [22]	train-rmse:6.83389	eval-rmse:7.58129
# [23]	train-rmse:6.76863	eval-rmse:7.54592
# [24]	train-rmse:6.71216	eval-rmse:7.51755
# [25]	train-rmse:6.66355	eval-rmse:7.49499
# [26]	train-rmse:6.61721	eval-rmse:7.46929
# [27]	train-rmse:6.57692	eval-rmse:7.45775
# [28]	train-rmse:6.54349	eval-rmse:7.44282
# [29]	train-rmse:6.5108	eval-rmse:7.42533
# [30]	train-rmse:6.48184	eval-rmse:7.41057
# [31]	train-rmse:6.45673	eval-rmse:7.39497
# [32]	train-rmse:6.43481	eval-rmse:7.3824
# [33]	train-rmse:6.4123	eval-rmse:7.36763
# [34]	train-rmse:6.39431	eval-rmse:7.36505
# [35]	train-rmse:6.37392	eval-rmse:7.35545
# [36]	train-rmse:6.35783	eval-rmse:7.35438
# [37]	train-rmse:6.34232	eval-rmse:7.35808
# [38]	train-rmse:6.32962	eval-rmse:7.36021
# [39]	train-rmse:6.31938	eval-rmse:7.36016
# [40]	train-rmse:6.30426	eval-rmse:7.35597
# [41]	train-rmse:6.2943	eval-rmse:7.35972
# [42]	train-rmse:6.28158	eval-rmse:7.3601
# [43]	train-rmse:6.2735	eval-rmse:7.35921
# [44]	train-rmse:6.26679	eval-rmse:7.35649
# [45]	train-rmse:6.25839	eval-rmse:7.36285
# [46]	train-rmse:6.25192	eval-rmse:7.35812
# [47]	train-rmse:6.24278	eval-rmse:7.35542
# [48]	train-rmse:6.23677	eval-rmse:7.35516
# [49]	train-rmse:6.23027	eval-rmse:7.34727
# [50]	train-rmse:6.22492	eval-rmse:7.34351
# [51]	train-rmse:6.21925	eval-rmse:7.34331
# [52]	train-rmse:6.21401	eval-rmse:7.34036
# [53]	train-rmse:6.20953	eval-rmse:7.33654
# [54]	train-rmse:6.204	eval-rmse:7.33546
# [55]	train-rmse:6.19821	eval-rmse:7.33697
# [56]	train-rmse:6.19449	eval-rmse:7.33613
# [57]	train-rmse:6.18939	eval-rmse:7.34529
# [58]	train-rmse:6.18217	eval-rmse:7.3391
# [59]	train-rmse:6.17803	eval-rmse:7.33899
# [60]	train-rmse:6.17151	eval-rmse:7.33754
# [61]	train-rmse:6.16583	eval-rmse:7.33468
# [62]	train-rmse:6.16223	eval-rmse:7.33294
# [63]	train-rmse:6.15831	eval-rmse:7.33385
# [64]	train-rmse:6.1546	eval-rmse:7.33304
# [65]	train-rmse:6.1496	eval-rmse:7.33742
# [66]	train-rmse:6.14532	eval-rmse:7.33509
# [67]	train-rmse:6.14217	eval-rmse:7.33615
# [68]	train-rmse:6.13911	eval-rmse:7.33717
# [69]	train-rmse:6.13494	eval-rmse:7.33603
# [70]	train-rmse:6.13255	eval-rmse:7.33924
# [71]	train-rmse:6.12816	eval-rmse:7.34047
# [72]	train-rmse:6.12565	eval-rmse:7.34069
# [73]	train-rmse:6.12194	eval-rmse:7.34152
# [74]	train-rmse:6.11651	eval-rmse:7.33861
# [75]	train-rmse:6.11265	eval-rmse:7.34044
# [76]	train-rmse:6.10762	eval-rmse:7.34915
# [77]	train-rmse:6.1054	eval-rmse:7.34842
# [78]	train-rmse:6.10161	eval-rmse:7.34536
# [79]	train-rmse:6.09594	eval-rmse:7.34316
# [80]	train-rmse:6.09056	eval-rmse:7.33593
# [81]	train-rmse:6.08432	eval-rmse:7.33482
# [82]	train-rmse:6.08178	eval-rmse:7.33657
# Stopping. Best iteration:
# [62]	train-rmse:6.16223	eval-rmse:7.33294

# %% [markdown]
# ### 損失関数の曲線

# %%
def draw_loss(evals_result):
    train_metric = evals_result['train']['rmse']
    plt.plot(train_metric, label='train rmse')
    eval_metric = evals_result['eval']['rmse']
    plt.plot(eval_metric, label='eval rmse')
    plt.grid()
    plt.legend()
    plt.title('loss curves')
    plt.xlabel('rounds')
    plt.ylabel('rmse')
    plt.show()
draw_loss(evals_result)

# %% [markdown]
# ### バリデーション結果と実測値

# %%
def draw_preds(model, d_val, df_val_Y, target, pred_type='validation'):
    d_pred_log = model.predict(d_val)
    d_pred = np.exp(d_pred_log)
    
    df_val_Y[f'{target}_pred'] = d_pred
    df_val_Y.to_excel(f'./output/{target}_{pred_type}.xlsx')

    plt.figure(figsize=(15,5))
    plt.plot(df_val_Y[target].values, label='real')
    plt.plot(d_pred, label='pred')
    plt.title('real and predicted values')
    plt.legend()
    plt.grid()
    plt.show()
draw_preds(model, d_val, df_val_Y, target)

# %% [markdown]
# ### 特徴量の寄与度

# %%
def draw_feat_importances(model):
    _, ax = plt.subplots(figsize=(15,30))
    xgb.plot_importance(model, ax=ax, importance_type='gain')
    plt.show()
draw_feat_importances(model)

# %%
fi = get_feat_importances(model)

# %% [markdown]
# ### 最適化されたパラメータで予測モデルを作成
# - テスト１：~2019/12/4を学習して2019/12/5~2019/12/11一週間を予測

# %%
# データの読込と前処理
in_dir = f'../data/two_years_each/test_1/{task}'
df_train_X, df_train_Y, df_val_X, df_val_Y = read_data(in_dir, target)

# xgboost のデータ構造に転換
d_train_sales, d_val_sales, d_val = mtx_trans(target, df_train_X, df_train_Y, df_val_X, df_val_Y)

# %%
# バリデーションにおいて最適化されたパラメータで学習
model, evals_result = train2(d_train_sales, d_val_sales, params, best_iter=best_iter, esr=None)
# Out:
# [0]	train-rmse:13.9796	eval-rmse:12.6097
# [1]	train-rmse:13.1837	eval-rmse:11.9882
# [2]	train-rmse:12.4665	eval-rmse:11.4503
# [3]	train-rmse:11.8119	eval-rmse:10.9442
# [4]	train-rmse:11.2192	eval-rmse:10.4823
# [5]	train-rmse:10.6847	eval-rmse:10.0887
# [6]	train-rmse:10.2057	eval-rmse:9.73532
# [7]	train-rmse:9.76922	eval-rmse:9.39483
# [8]	train-rmse:9.37903	eval-rmse:9.09444
# [9]	train-rmse:9.03307	eval-rmse:8.84296
# [10]	train-rmse:8.72199	eval-rmse:8.61577
# [11]	train-rmse:8.44956	eval-rmse:8.41024
# [12]	train-rmse:8.20216	eval-rmse:8.23269
# [13]	train-rmse:7.98162	eval-rmse:8.06801
# [14]	train-rmse:7.78669	eval-rmse:7.93762
# [15]	train-rmse:7.61376	eval-rmse:7.80227
# [16]	train-rmse:7.46342	eval-rmse:7.68513
# [17]	train-rmse:7.33047	eval-rmse:7.59678
# [18]	train-rmse:7.21012	eval-rmse:7.50537
# [19]	train-rmse:7.10548	eval-rmse:7.42844
# [20]	train-rmse:7.01219	eval-rmse:7.35842
# [21]	train-rmse:6.93037	eval-rmse:7.30581
# [22]	train-rmse:6.85896	eval-rmse:7.25975
# [23]	train-rmse:6.79638	eval-rmse:7.2141
# [24]	train-rmse:6.7375	eval-rmse:7.17372
# [25]	train-rmse:6.68809	eval-rmse:7.13496
# [26]	train-rmse:6.64244	eval-rmse:7.09424
# [27]	train-rmse:6.60431	eval-rmse:7.06531
# [28]	train-rmse:6.56857	eval-rmse:7.05201
# [29]	train-rmse:6.5388	eval-rmse:7.03925
# [30]	train-rmse:6.51079	eval-rmse:7.03136
# [31]	train-rmse:6.48453	eval-rmse:7.01849
# [32]	train-rmse:6.4615	eval-rmse:7.01037
# [33]	train-rmse:6.43838	eval-rmse:6.99697
# [34]	train-rmse:6.41947	eval-rmse:6.98215
# [35]	train-rmse:6.4023	eval-rmse:6.97633
# [36]	train-rmse:6.38594	eval-rmse:6.96682
# [37]	train-rmse:6.37077	eval-rmse:6.96657
# [38]	train-rmse:6.35537	eval-rmse:6.94926
# [39]	train-rmse:6.34165	eval-rmse:6.92522
# [40]	train-rmse:6.33183	eval-rmse:6.92344
# [41]	train-rmse:6.32299	eval-rmse:6.91793
# [42]	train-rmse:6.31322	eval-rmse:6.90909
# [43]	train-rmse:6.30275	eval-rmse:6.8852
# [44]	train-rmse:6.29573	eval-rmse:6.8864
# [45]	train-rmse:6.28791	eval-rmse:6.89115
# [46]	train-rmse:6.28167	eval-rmse:6.88935
# [47]	train-rmse:6.2762	eval-rmse:6.88392
# [48]	train-rmse:6.2692	eval-rmse:6.88413
# [49]	train-rmse:6.26234	eval-rmse:6.88417
# [50]	train-rmse:6.25529	eval-rmse:6.86408
# [51]	train-rmse:6.24956	eval-rmse:6.86851
# [52]	train-rmse:6.2434	eval-rmse:6.8641
# [53]	train-rmse:6.23535	eval-rmse:6.85453
# [54]	train-rmse:6.22961	eval-rmse:6.84845
# [55]	train-rmse:6.22551	eval-rmse:6.84689
# [56]	train-rmse:6.22021	eval-rmse:6.84692
# [57]	train-rmse:6.21526	eval-rmse:6.83981
# [58]	train-rmse:6.21224	eval-rmse:6.83559
# [59]	train-rmse:6.2078	eval-rmse:6.83691
# [60]	train-rmse:6.20239	eval-rmse:6.83608
# [61]	train-rmse:6.19906	eval-rmse:6.83519

# %%
draw_loss(evals_result)
draw_preds(model, d_val, df_val_Y, target, 'test1')
draw_feat_importances(model)

# %% [markdown]
# - テスト２：~2019-12-11を学習して2019-12-12~2019-12-18一週間を予測

# %%
# データの読込と前処理
in_dir = f'../data/two_years_each/test_2/{task}'
df_train_X, df_train_Y, df_val_X, df_val_Y = read_data(in_dir, target)

# xgboost のデータ構造に転換
d_train_sales, d_val_sales, d_val = mtx_trans(target, df_train_X, df_train_Y, df_val_X, df_val_Y)

# %%
# バリデーションにおいて最適化されたパラメータで学習
model, evals_result = train2(d_train_sales, d_val_sales, params, best_iter=best_iter, esr=None)
# Out:
# [0]	train-rmse:13.9669	eval-rmse:12.8387
# [1]	train-rmse:13.1848	eval-rmse:12.1922
# [2]	train-rmse:12.4616	eval-rmse:11.5886
# [3]	train-rmse:11.8072	eval-rmse:11.044
# [4]	train-rmse:11.2142	eval-rmse:10.5522
# [5]	train-rmse:10.6854	eval-rmse:10.1357
# [6]	train-rmse:10.2031	eval-rmse:9.75216
# [7]	train-rmse:9.77449	eval-rmse:9.40203
# [8]	train-rmse:9.3833	eval-rmse:9.0614
# [9]	train-rmse:9.03538	eval-rmse:8.78402
# [10]	train-rmse:8.72826	eval-rmse:8.54474
# [11]	train-rmse:8.44736	eval-rmse:8.32177
# [12]	train-rmse:8.20345	eval-rmse:8.11993
# [13]	train-rmse:7.98874	eval-rmse:7.94613
# [14]	train-rmse:7.79755	eval-rmse:7.78635
# [15]	train-rmse:7.62505	eval-rmse:7.64481
# [16]	train-rmse:7.47327	eval-rmse:7.51252
# [17]	train-rmse:7.33658	eval-rmse:7.39439
# [18]	train-rmse:7.21768	eval-rmse:7.28972
# [19]	train-rmse:7.11304	eval-rmse:7.19024
# [20]	train-rmse:7.02239	eval-rmse:7.11887
# [21]	train-rmse:6.94011	eval-rmse:7.03925
# [22]	train-rmse:6.86825	eval-rmse:6.9731
# [23]	train-rmse:6.805	eval-rmse:6.92285
# [24]	train-rmse:6.74983	eval-rmse:6.86734
# [25]	train-rmse:6.69897	eval-rmse:6.81472
# [26]	train-rmse:6.65461	eval-rmse:6.78378
# [27]	train-rmse:6.61618	eval-rmse:6.75341
# [28]	train-rmse:6.58025	eval-rmse:6.71737
# [29]	train-rmse:6.54749	eval-rmse:6.6783
# [30]	train-rmse:6.51949	eval-rmse:6.63925
# [31]	train-rmse:6.49571	eval-rmse:6.61758
# [32]	train-rmse:6.47421	eval-rmse:6.59736
# [33]	train-rmse:6.45406	eval-rmse:6.57805
# [34]	train-rmse:6.43566	eval-rmse:6.56167
# [35]	train-rmse:6.41922	eval-rmse:6.53925
# [36]	train-rmse:6.40447	eval-rmse:6.52535
# [37]	train-rmse:6.38966	eval-rmse:6.52288
# [38]	train-rmse:6.37879	eval-rmse:6.50971
# [39]	train-rmse:6.36655	eval-rmse:6.49988
# [40]	train-rmse:6.3565	eval-rmse:6.49355
# [41]	train-rmse:6.34671	eval-rmse:6.48364
# [42]	train-rmse:6.33547	eval-rmse:6.48183
# [43]	train-rmse:6.32767	eval-rmse:6.4793
# [44]	train-rmse:6.31872	eval-rmse:6.46967
# [45]	train-rmse:6.31202	eval-rmse:6.46788
# [46]	train-rmse:6.30331	eval-rmse:6.46684
# [47]	train-rmse:6.29443	eval-rmse:6.46289
# [48]	train-rmse:6.28961	eval-rmse:6.46525
# [49]	train-rmse:6.28487	eval-rmse:6.46209
# [50]	train-rmse:6.27949	eval-rmse:6.4555
# [51]	train-rmse:6.2708	eval-rmse:6.45453
# [52]	train-rmse:6.26383	eval-rmse:6.44582
# [53]	train-rmse:6.2589	eval-rmse:6.44444
# [54]	train-rmse:6.25201	eval-rmse:6.4452
# [55]	train-rmse:6.24852	eval-rmse:6.44346
# [56]	train-rmse:6.24247	eval-rmse:6.43306
# [57]	train-rmse:6.23658	eval-rmse:6.44146
# [58]	train-rmse:6.23021	eval-rmse:6.44069
# [59]	train-rmse:6.2266	eval-rmse:6.44032
# [60]	train-rmse:6.22032	eval-rmse:6.43951
# [61]	train-rmse:6.21528	eval-rmse:6.44671

# %%
draw_loss(evals_result)
draw_preds(model, d_val, df_val_Y, target, 'test2')
draw_feat_importances(model)
