# %%
import sys
sys.path.append('../')
from functions import *
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### データ読込

# %%
task, target = 'skip', 'ClicksSum'
in_dir = f'../data/two_years_each/val/{task}'
df_train_X, df_train_Y, df_val_X, df_val_Y = read_data(in_dir, target)
# Out:
# ../functions.py:28: FutureWarning: `weekday_name` is deprecated and will be removed in a future version. Use `day_name` instead
#   return m[x.name.weekday_name]
# ../functions.py:24: FutureWarning: `weekday_name` is deprecated and will be removed in a future version. Use `day_name` instead
#   return 1 if x.name.weekday_name in ['Saturday', 'Sunday'] else 0

# %% [markdown]
# ### 目的変数の分布

# %%
sns.distplot(np.log(df_train_Y[target] + 0.00000001))
plt.plot()
# Out:
# []

# %% [markdown]
# ### データ構造転換

# %%
d_train_sales, d_val_sales, d_val = mtx_trans(target, df_train_X, df_train_Y, df_val_X, df_val_Y)
# Out:
# /Users/dushu/opt/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /Users/dushu/opt/anaconda3/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %% [markdown]
# ### パラメータのベイズ最適化

# %%
#params = optimize()
#params

# %% [markdown]
# ### xgboost のバリデーションモデルを作成
# - 最適化されたパラメータでモデルを作成

# %%
params = {'alpha': 5.381322057246327e-07,
 'colsample_bytree': 0.9,
 'eta': 0.2,
 'gamma': 1.6528274970932927e-07,
 'lambda': 6.950129325371027e-05,
 'max_depth': 6,
 'min_child_weight': 0.5694636899058642,
 'n_estimators': 664.0,
 'subsample': 0.9}

model, evals_result = train2(d_train_sales, d_val_sales, params)
best_iter = model.best_iteration
# Out:
# [0]	train-rmse:5.27229	eval-rmse:5.41509
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:4.27696	eval-rmse:4.35069
# [2]	train-rmse:3.48942	eval-rmse:3.49719
# [3]	train-rmse:2.87342	eval-rmse:2.81774
# [4]	train-rmse:2.39229	eval-rmse:2.27662
# [5]	train-rmse:2.0214	eval-rmse:1.84331
# [6]	train-rmse:1.7371	eval-rmse:1.50075
# [7]	train-rmse:1.5269	eval-rmse:1.2339
# [8]	train-rmse:1.36977	eval-rmse:1.02197
# [9]	train-rmse:1.25412	eval-rmse:0.859255
# [10]	train-rmse:1.16854	eval-rmse:0.735474
# [11]	train-rmse:1.1096	eval-rmse:0.641053
# [12]	train-rmse:1.06361	eval-rmse:0.573986
# [13]	train-rmse:1.03014	eval-rmse:0.524285
# [14]	train-rmse:1.00172	eval-rmse:0.489576
# [15]	train-rmse:0.979085	eval-rmse:0.463979
# [16]	train-rmse:0.9603	eval-rmse:0.444804
# [17]	train-rmse:0.948078	eval-rmse:0.432527
# [18]	train-rmse:0.930405	eval-rmse:0.425212
# [19]	train-rmse:0.906839	eval-rmse:0.423538
# [20]	train-rmse:0.894131	eval-rmse:0.420321
# [21]	train-rmse:0.876409	eval-rmse:0.417374
# [22]	train-rmse:0.861129	eval-rmse:0.416116
# [23]	train-rmse:0.854878	eval-rmse:0.413774
# [24]	train-rmse:0.840879	eval-rmse:0.413536
# [25]	train-rmse:0.828191	eval-rmse:0.412977
# [26]	train-rmse:0.819006	eval-rmse:0.411063
# [27]	train-rmse:0.810093	eval-rmse:0.410723
# [28]	train-rmse:0.805441	eval-rmse:0.410256
# [29]	train-rmse:0.800141	eval-rmse:0.410088
# [30]	train-rmse:0.793784	eval-rmse:0.412144
# [31]	train-rmse:0.787416	eval-rmse:0.411797
# [32]	train-rmse:0.777382	eval-rmse:0.412716
# [33]	train-rmse:0.775152	eval-rmse:0.41286
# [34]	train-rmse:0.767009	eval-rmse:0.412816
# [35]	train-rmse:0.761198	eval-rmse:0.412822
# [36]	train-rmse:0.754901	eval-rmse:0.412797
# [37]	train-rmse:0.747816	eval-rmse:0.41287
# [38]	train-rmse:0.74299	eval-rmse:0.414723
# [39]	train-rmse:0.73618	eval-rmse:0.417254
# [40]	train-rmse:0.728451	eval-rmse:0.417346
# [41]	train-rmse:0.721862	eval-rmse:0.420975
# [42]	train-rmse:0.718503	eval-rmse:0.421158
# [43]	train-rmse:0.713969	eval-rmse:0.421687
# [44]	train-rmse:0.706765	eval-rmse:0.420844
# [45]	train-rmse:0.703187	eval-rmse:0.419988
# [46]	train-rmse:0.699496	eval-rmse:0.419403
# [47]	train-rmse:0.695016	eval-rmse:0.425742
# [48]	train-rmse:0.68415	eval-rmse:0.42803
# [49]	train-rmse:0.674476	eval-rmse:0.433187
# Stopping. Best iteration:
# [29]	train-rmse:0.800141	eval-rmse:0.410088

# %% [markdown]
# ### 損失関数の曲線

# %%
def draw_loss(evals_result):
    train_metric = evals_result['train']['rmse']
    plt.plot(train_metric, label='train rmse')
    eval_metric = evals_result['eval']['rmse']
    plt.plot(eval_metric, label='eval rmse')
    plt.grid()
    plt.legend()
    plt.title('loss curves')
    plt.xlabel('rounds')
    plt.ylabel('rmse')
    plt.show()
draw_loss(evals_result)

# %% [markdown]
# ### バリデーション結果と実測値

# %%
def draw_preds(model, d_val, df_val_Y, target, pred_type='validation'):
    d_pred_log = model.predict(d_val)
    d_pred = np.exp(d_pred_log)
    
    df_val_Y[f'{target}_pred'] = d_pred
    df_val_Y.to_excel(f'./output/{target}_{pred_type}.xlsx')

    plt.figure(figsize=(15,5))
    plt.plot(df_val_Y[target].values, label='real')
    plt.plot(d_pred, label='pred')
    plt.title('real and predicted values')
    plt.legend()
    plt.grid()
    plt.show()
draw_preds(model, d_val, df_val_Y, target)

# %% [markdown]
# ### 特徴量の寄与度

# %%
def draw_feat_importances(model):
    _, ax = plt.subplots(figsize=(15,30))
    xgb.plot_importance(model, ax=ax, importance_type='gain')
    plt.show()
draw_feat_importances(model)

# %%
fi = get_feat_importances(model)

# %% [markdown]
# ### 最適化されたパラメータで予測モデルを作成
# - テスト１：~2019/12/4を学習して2019/12/5~2019/12/11一週間を予測

# %%
# データの読込と前処理
in_dir = f'../data/two_years_each/test_1/{task}'
df_train_X, df_train_Y, df_val_X, df_val_Y = read_data(in_dir, target)

# xgboost のデータ構造に転換
d_train_sales, d_val_sales, d_val = mtx_trans(target, df_train_X, df_train_Y, df_val_X, df_val_Y)

# %%
# バリデーションにおいて最適化されたパラメータで学習
model, evals_result = train2(d_train_sales, d_val_sales, params, best_iter=best_iter, esr=None)
# Out:
# [0]	train-rmse:5.27604	eval-rmse:5.69321
# [1]	train-rmse:4.27704	eval-rmse:4.60118
# [2]	train-rmse:3.48702	eval-rmse:3.72515
# [3]	train-rmse:2.86631	eval-rmse:3.02614
# [4]	train-rmse:2.38074	eval-rmse:2.4698
# [5]	train-rmse:2.0099	eval-rmse:2.03225
# [6]	train-rmse:1.72349	eval-rmse:1.68353
# [7]	train-rmse:1.50602	eval-rmse:1.40446
# [8]	train-rmse:1.34937	eval-rmse:1.18632
# [9]	train-rmse:1.23214	eval-rmse:1.02461
# [10]	train-rmse:1.14736	eval-rmse:0.889917
# [11]	train-rmse:1.08602	eval-rmse:0.789776
# [12]	train-rmse:1.04277	eval-rmse:0.71399
# [13]	train-rmse:1.01019	eval-rmse:0.655185
# [14]	train-rmse:0.983773	eval-rmse:0.607931
# [15]	train-rmse:0.959018	eval-rmse:0.573911
# [16]	train-rmse:0.937557	eval-rmse:0.545362
# [17]	train-rmse:0.924225	eval-rmse:0.526671
# [18]	train-rmse:0.899577	eval-rmse:0.510873
# [19]	train-rmse:0.884457	eval-rmse:0.500104
# [20]	train-rmse:0.868247	eval-rmse:0.491965
# [21]	train-rmse:0.852004	eval-rmse:0.481403
# [22]	train-rmse:0.845075	eval-rmse:0.476557
# [23]	train-rmse:0.833676	eval-rmse:0.472924
# [24]	train-rmse:0.827722	eval-rmse:0.469266
# [25]	train-rmse:0.816907	eval-rmse:0.4635
# [26]	train-rmse:0.802066	eval-rmse:0.461534
# [27]	train-rmse:0.794577	eval-rmse:0.456789
# [28]	train-rmse:0.788171	eval-rmse:0.45336

# %%
draw_loss(evals_result)
draw_preds(model, d_val, df_val_Y, target, 'test1')
draw_feat_importances(model)

# %% [markdown]
# - テスト２：~2019-12-11を学習して2019-12-12~2019-12-18一週間を予測

# %%
# データの読込と前処理
in_dir = f'../data/two_years_each/test_2/{task}'
df_train_X, df_train_Y, df_val_X, df_val_Y = read_data(in_dir, target)

# xgboost のデータ構造に転換
d_train_sales, d_val_sales, d_val = mtx_trans(target, df_train_X, df_train_Y, df_val_X, df_val_Y)

# %%
# バリデーションにおいて最適化されたパラメータで学習
model, evals_result = train2(d_train_sales, d_val_sales, params, best_iter=best_iter, esr=None)
# Out:
# [0]	train-rmse:5.28253	eval-rmse:5.39439
# [1]	train-rmse:4.28054	eval-rmse:4.27974
# [2]	train-rmse:3.49002	eval-rmse:3.38756
# [3]	train-rmse:2.86794	eval-rmse:2.72845
# [4]	train-rmse:2.38099	eval-rmse:2.16605
# [5]	train-rmse:2.00742	eval-rmse:1.81271
# [6]	train-rmse:1.72086	eval-rmse:1.47689
# [7]	train-rmse:1.50791	eval-rmse:1.22161
# [8]	train-rmse:1.35005	eval-rmse:1.07729
# [9]	train-rmse:1.23255	eval-rmse:0.944329
# [10]	train-rmse:1.14722	eval-rmse:0.852877
# [11]	train-rmse:1.07776	eval-rmse:0.792799
# [12]	train-rmse:1.03463	eval-rmse:0.753562
# [13]	train-rmse:1.00022	eval-rmse:0.706192
# [14]	train-rmse:0.971711	eval-rmse:0.693846
# [15]	train-rmse:0.9556	eval-rmse:0.688554
# [16]	train-rmse:0.935213	eval-rmse:0.686445
# [17]	train-rmse:0.919174	eval-rmse:0.685134
# [18]	train-rmse:0.898749	eval-rmse:0.684591
# [19]	train-rmse:0.884055	eval-rmse:0.68751
# [20]	train-rmse:0.869008	eval-rmse:0.6947
# [21]	train-rmse:0.862595	eval-rmse:0.695518
# [22]	train-rmse:0.848254	eval-rmse:0.699281
# [23]	train-rmse:0.832513	eval-rmse:0.699785
# [24]	train-rmse:0.820691	eval-rmse:0.700532
# [25]	train-rmse:0.810562	eval-rmse:0.897551
# [26]	train-rmse:0.801979	eval-rmse:0.97411
# [27]	train-rmse:0.790405	eval-rmse:0.996953
# [28]	train-rmse:0.783133	eval-rmse:0.99743

# %%
draw_loss(evals_result)
draw_preds(model, d_val, df_val_Y, target, 'test2')
draw_feat_importances(model)
